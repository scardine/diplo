# %%
import sys, os
sys.path.append('/Users/paulos/Documents/work/diplo')
os.environ['DJANGO_SETTINGS_MODULE'] = 'diplo.settings'

from django.core.wsgi import get_wsgi_application
application = get_wsgi_application()

# %% [markdown]
# # Classificação das categorias
#
# ## Demográfico
#
# Esta é simples, todas as variáveis são da sub-categoria "População e território".

# %%
# Colado da planilha
variaveis = [_.strip() for _ in """Pop2000
Pop2008
Pop2009
Pop2010
Pop2011
Pop2012
Pop2013
Pop2014
Pop2015


Pop2010_Masc0a4
Pop2010_Masc5a9
Pop2010_Masc10a14
Pop2010_Masc15a19
Pop2010_Masc20a24
Pop2010_Masc25a29
Pop2010_Masc30a34
Pop2010_Masc35a39
Pop2010_Masc40a44
Pop2010_Masc45a49
Pop2010_Masc50a54
Pop2010_Masc55a59
Pop2010_Masc60a64
Pop2010_Masc65a69
Pop2010_Masc70a74
Pop2010_Masc75mais
Pop2010_Fem0a4
Pop2010_Fem5a9
Pop2010_Fem10a14
Pop2010_Fem15a19
Pop2010_Fem20a24
Pop2010_Fem25a29
Pop2010_Fem30a34
Pop2010_Fem35a39
Pop2010_Fem40a44
Pop2010_Fem45a49
Pop2010_Fem50a54
Pop2010_Fem55a59
Pop2010_Fem60a64
Pop2010_Fem65a69
Pop2010_Fem70a74
Pop2010_Fem75mais
Pop2015_Masc0a4
Pop2015_Masc5a9
Pop2015_Masc10a14
Pop2015_Masc15a19
Pop2015_Masc20a24
Pop2015_Masc25a29
Pop2015_Masc30a34
Pop2015_Masc35a39
Pop2015_Masc40a44
Pop2015_Masc45a49
Pop2015_Masc50a54
Pop2015_Masc55a59
Pop2015_Masc60a64
Pop2015_Masc65a69
Pop2015_Masc70a74
Pop2015_Masc75mais
Pop2015_Fem0a4
Pop2015_Fem5a9
Pop2015_Fem10a14
Pop2015_Fem15a19
Pop2015_Fem20a24
Pop2015_Fem25a29
Pop2015_Fem30a34
Pop2015_Fem35a39
Pop2015_Fem40a44
Pop2015_Fem45a49
Pop2015_Fem50a54
Pop2015_Fem55a59
Pop2015_Fem60a64
Pop2015_Fem65a69
Pop2015_Fem70a74
Pop2015_Fem75mais
Pop2020_Masc0a4
Pop2020_Masc5a9
Pop2020_Masc10a14
Pop2020_Masc15a19
Pop2020_Masc20a24
Pop2020_Masc25a29
Pop2020_Masc30a34
Pop2020_Masc35a39
Pop2020_Masc40a44
Pop2020_Masc45a49
Pop2020_Masc50a54
Pop2020_Masc55a59
Pop2020_Masc60a64
Pop2020_Masc65a69
Pop2020_Masc70a74
Pop2020_Masc75mais
Pop2020_Fem0a4
Pop2020_Fem5a9
Pop2020_Fem10a14
Pop2020_Fem15a19
Pop2020_Fem20a24
Pop2020_Fem25a29
Pop2020_Fem30a34
Pop2020_Fem35a39
Pop2020_Fem40a44
Pop2020_Fem45a49
Pop2020_Fem50a54
Pop2020_Fem55a59
Pop2020_Fem60a64
Pop2020_Fem65a69
Pop2020_Fem70a74
Pop2020_Fem75mais
Pop2030_Masc0a4
Pop2030_Masc5a9
Pop2030_Masc10a14
Pop2030_Masc15a19
Pop2030_Masc20a24
Pop2030_Masc25a29
Pop2030_Masc30a34
Pop2030_Masc35a39
Pop2030_Masc40a44
Pop2030_Masc45a49
Pop2030_Masc50a54
Pop2030_Masc55a59
Pop2030_Masc60a64
Pop2030_Masc65a69
Pop2030_Masc70a74
Pop2030_Masc75mais
Pop2030_Fem0a4
Pop2030_Fem5a9
Pop2030_Fem10a14
Pop2030_Fem15a19
Pop2030_Fem20a24
Pop2030_Fem25a29
Pop2030_Fem30a34
Pop2030_Fem35a39
Pop2030_Fem40a44
Pop2030_Fem45a49
Pop2030_Fem50a54
Pop2030_Fem55a59
Pop2030_Fem60a64
Pop2030_Fem65a69
Pop2030_Fem70a74
Pop2030_Fem75mais
DENSIDADE_10
TXCRESC00_10
TXENV_10
TXURB_10
ESPVIDA_10""".upper().split() if _.strip()]

# %%
from data.models import *

# %%
c = Categoria.objects.get(slug="demografico--populacao-e-territorio")
c
# Out:
# <Categoria: Demográfico > População e Território>

# %%
for i in Indicador.objects.all():
    vars = set(i.observacao.upper().split(','))
    if vars.intersection(variaveis):
        print "encontrado", var, "em:", i 
        i.categoria = c
        i.save()
# Out:
# encontrado ESPVIDA_10 em: Densidade demográfica - habitantes por km2
# encontrado ESPVIDA_10 em: Esperança de vida ao nascer
# encontrado ESPVIDA_10 em: Homens - 00 a 04 anos
# encontrado ESPVIDA_10 em: Homens - 05 a 09 anos
# encontrado ESPVIDA_10 em: Homens - 10 a 14 anos
# encontrado ESPVIDA_10 em: Homens - 15 a 19 anos
# encontrado ESPVIDA_10 em: Homens - 20 a 24 anos
# encontrado ESPVIDA_10 em: Homens - 25 a 29 anos
# encontrado ESPVIDA_10 em: Homens - 30 a 34 anos
# encontrado ESPVIDA_10 em: Homens - 35 a 39 anos
# encontrado ESPVIDA_10 em: Homens - 40 a 44 anos
# encontrado ESPVIDA_10 em: Homens - 45 a 49 anos
# encontrado ESPVIDA_10 em: Homens - 50 a 54 anos
# encontrado ESPVIDA_10 em: Homens - 55 a 59 anos
# encontrado ESPVIDA_10 em: Homens - 60 a 64 anos
# encontrado ESPVIDA_10 em: Homens - 65 a 69 anos
# encontrado ESPVIDA_10 em: Homens - 70 a 74 anos
# encontrado ESPVIDA_10 em: Homens - 75 anos e mais
# encontrado ESPVIDA_10 em: Mulheres - 00 a 04 anos
# ...

# %% [markdown]
# ## Socioeconômicos
#
# Esta tem mais subcategorias. Vejamos:

# %%
variaveis = {}

for subcat, var in [_.split("\t") for _ in u"""Economia	PIBPC_13
Economia	P_VA_AGRO_13
Economia	P_VA_IND_13
Economia	P_VA_SERV_13
Economia	P_VA_ADM_13
Renda e pobreza	RENDADOM_PC_2010
Renda e pobreza	P_EXTPOB_10
Renda e pobreza	P_POB_10
Renda e pobreza	P_VULNPOB_10
Escolaridade	TXANALF15_10
Escolaridade	P_EFCOMP_10
Escolaridade	P_EMCOMP_10
Trabalho e rendimentos	TXDESOC_10
Trabalho e rendimentos	TXATIVID_10
Trabalho e rendimentos	PUB_CART_10
Trabalho e rendimentos	RENDTRPR_10
Infraestrutura urbana	AGUA_10
Infraestrutura urbana	ESGOTO_10
Infraestrutura urbana	LIXO_10
Infraestrutura urbana	ENERGIA_10""".upper().split("\n")]:
    variaveis.setdefault(subcat, set()).add(var)
    
variaveis
# Out:
# {u'ECONOMIA': {u'PIBPC_13',
#   u'P_VA_ADM_13',
#   u'P_VA_AGRO_13',
#   u'P_VA_IND_13',
#   u'P_VA_SERV_13'},
#  u'ESCOLARIDADE': {u'P_EFCOMP_10', u'P_EMCOMP_10', u'TXANALF15_10'},
#  u'INFRAESTRUTURA URBANA': {u'AGUA_10',
#   u'ENERGIA_10',
#   u'ESGOTO_10',
#   u'LIXO_10'},
#  u'RENDA E POBREZA': {u'P_EXTPOB_10',
#   u'P_POB_10',
#   u'P_VULNPOB_10',
#   u'RENDADOM_PC_2010'},
#  u'TRABALHO E RENDIMENTOS': {u'PUB_CART_10',
#   u'RENDTRPR_10',
#   u'TXATIVID_10',
#   u'TXDESOC_10'}}

# %%
from unidecode import unidecode
c = Categoria.objects.get(slug='socioeconomico')

# %%
for s in variaveis:
    slug = c.slug+'--'+"-".join(unidecode(s).lower().split())
    try: 
        sc = Categoria.objects.get(slug__startswith=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[s]):
            print "encontrado", slug, "em:", i 
            i.categoria = sc
            i.save()
# Out:
# encontrado socioeconomico--economia em: Participação percentual do valor adicionado da administração pública no valor adicionado total
# encontrado socioeconomico--economia em: Participação percentual do valor adicionado da agropecuária no valor adicionado total
# encontrado socioeconomico--economia em: Participação percentual do valor adicionado da indústria no valor adicionado total
# encontrado socioeconomico--economia em: Participação percentual do valor adicionado do comércio e serviços (exceto administração pública) no valor adicionado total
# encontrado socioeconomico--economia em: Produto Interno Bruto per capita (R$ 1,00)
# encontrado socioeconomico--renda-e-pobreza em: Proporção de pessoas com renda domiciliar per capita igual ou inferior a R$ 140,00
# encontrado socioeconomico--renda-e-pobreza em: Proporção de pessoas com renda domiciliar per capita igual ou inferior a R$ 255,00 (1/2 salário mínimo)
# ...

# %% [markdown]
# ## Mortalidade
#
# Esta categoria tem 3 subníveis!

# %%
c = Categoria.objects.get(slug='mortalidade', depth=1)

variaveis = {}

for subcat, subsubcat, var in [_.split("\t") for _ in u"""Mortalidade Infantil	Taxas	TXMORTINF_08
Mortalidade Infantil	Taxas	TXMORTINF_09
Mortalidade Infantil	Taxas	TXMORTINF_10
Mortalidade Infantil	Taxas	TXMORTINF_11
Mortalidade Infantil	Taxas	TXMORTINF_12
Mortalidade Infantil	Taxas	TXMORTINF_13
Mortalidade Infantil	Taxas	TXMORTINF_14
Mortalidade Infantil	Taxas	TXMORTNEOP_08
Mortalidade Infantil	Taxas	TXMORTNEOP_09
Mortalidade Infantil	Taxas	TXMORTNEOP_10
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_08
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_09
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_10
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_11
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_12
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_13
Mortalidade por causas selecionadas	Óbitos	ObNeopColUt_14
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_08
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_09
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_10
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_11
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_12
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_13
Mortalidade por causas selecionadas	Óbitos	ObNeopMama_14
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_08
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_09
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_10
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_11
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_12
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_13
Mortalidade por causas selecionadas	Óbitos	ObNeopProst_14
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_08
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_09
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_10
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_11
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_12
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_13
Mortalidade por causas selecionadas	Óbitos	ObNeoTBP_14
Mortalidade por causas selecionadas	Óbitos	ObDCNT_08
Mortalidade por causas selecionadas	Óbitos	ObDCNT_09
Mortalidade por causas selecionadas	Óbitos	ObDCNT_10
Mortalidade por causas selecionadas	Óbitos	ObDCNT_11
Mortalidade por causas selecionadas	Óbitos	ObDCNT_12
Mortalidade por causas selecionadas	Óbitos	ObDCNT_13""".upper().split("\n")]:
    variaveis.setdefault((subcat, subsubcat), set()).add(var)
    
variaveis
# Out:
# {(u'MORTALIDADE INFANTIL', u'NASCIDOS VIVOS'): {u'NV_08',
#   u'NV_09',
#   u'NV_10',
#   u'NV_11',
#   u'NV_12',
#   u'NV_13',
#   u'NV_14'},
#  (u'MORTALIDADE INFANTIL', u'TAXAS'): {u'MORTPROPDDA_08',
#   u'MORTPROPDDA_09',
#   u'MORTPROPDDA_10',
#   u'MORTPROPDDA_11',
#   u'MORTPROPDDA_12',
#   u'MORTPROPDDA_13',
#   u'MORTPROPDDA_14',
#   u'TXMORTINF_08',
#   u'TXMORTINF_09',
#   u'TXMORTINF_10',
#   u'TXMORTINF_11',
#   u'TXMORTINF_12',
#   u'TXMORTINF_13',
#   u'TXMORTINF_14',
#   u'TXMORTNEOP_08',
#   u'TXMORTNEOP_09',
#   u'TXMORTNEOP_10',
#   u'TXMORTNEOP_11',
#   u'TXMORTNEOP_12',
#   u'TXMORTNEOP_13',
#   u'TXMORTNEOP_14',
#   u'TXMORTNEOT_08',
#   u'TXMORTNEOT_09',
#   u'TXMORTNEOT_10',
#   u'TXMORTNEOT_11',
#   u'TXMORTNEOT_12',
#   u'TXMORTNEOT_13',
#   u'TXMORTNEOT_14',
#   u'TXMORTPOSN_08',
#   u'TXMORTPOSN_09',
#   u'TXMORTPOSN_10',
#   u'TXMORTPOSN_11',
#   u'TXMORTPOSN_12',
#   u'TXMORTPOSN_13',
#   u'TXMORTPOSN_14'},
# ...

# %%
for s, ss in variaveis:
    slug = c.slug+'--'+"--".join([
            "-".join(unidecode(s).lower().split()),
            "-".join(unidecode(ss).lower().split()),
        ])
    try: 
        ssc = Categoria.objects.get(slug=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[(s, ss)]):
            print "encontrado", slug, "em:", i 
            i.categoria = ssc
            i.save()
# Out:
# encontrado mortalidade--mortalidade-infantil--taxas em: Mortalidade proporcional por Doença Diarréica Aguda (DDA) em menores de 5 anos (em %)
# encontrado mortalidade--mortalidade-infantil--taxas em: Taxa de mortalidade infantil - menores de 1 ano (em 1.000 nascidos vivos)
# encontrado mortalidade--mortalidade-infantil--taxas em: Taxa de mortalidade neonatal precoce - 0 a 6 dias (em 1.000 nascidos vivos)
# encontrado mortalidade--mortalidade-infantil--taxas em: Taxa de mortalidade neonatal tardia - 7 a 27 dias (em 1.000 nascidos vivos)
# encontrado mortalidade--mortalidade-infantil--taxas em: Taxa de mortalidade pós-neonatal - 28 a 364 dias (em 1.000 nascidos vivos)
# encontrado mortalidade--mortalidade-infantil--nascidos-vivos em: Nascidos vivos
# encontrado mortalidade--mortalidade-materna--obitos em: Óbitos maternos
# categoria nao encontrada para slug mortalidade--mortalidade-infantil--obitos
# ...

# %%
morbidade_txt = u"""Morbidade hospitalar	Taxas	INTERNNEO_09
Morbidade hospitalar	Taxas	INTERNNEO_10
Morbidade hospitalar	Taxas	INTERNNEO_11
Morbidade hospitalar	Taxas	INTERNNEO_12
Morbidade hospitalar	Taxas	INTERNNEO_13
Morbidade hospitalar	Taxas	INTERNNEO_14
Morbidade hospitalar	Taxas	INTERNDAC_08
Morbidade hospitalar	Taxas	INTERNDAC_09
Morbidade hospitalar	Taxas	INTERNDAC_10
Morbidade hospitalar	Taxas	INTERNDAC_11
Morbidade hospitalar	Taxas	INTERNDAC_12
Morbidade hospitalar	Taxas	INTERNDAC_13
Morbidade hospitalar	Taxas	INTERNDAC_14
Morbidade hospitalar	Taxas	INTERNCEMM_08
Morbidade hospitalar	Taxas	INTERNCEMM_09
Morbidade hospitalar	Taxas	INTERNCEMM_10
Morbidade hospitalar	Taxas	INTERNCEMM_11
Morbidade hospitalar	Taxas	INTERNCEMM_12
Doenças transmissíveis	Incidência	Zika_08
Doenças transmissíveis	Incidência	Zika_09
Doenças transmissíveis	Incidência	Zika_10
Doenças transmissíveis	Incidência	Zika_11
Doenças transmissíveis	Incidência	Zika_12
Doenças transmissíveis	Incidência	Zika_13
Doenças transmissíveis	Incidência	Zika_14
Doenças transmissíveis	Incidência	Chikung_08
Doenças transmissíveis	Incidência	Chikung_09
Doenças transmissíveis	Incidência	Chikung_10
Doenças transmissíveis	Incidência	Chikung_11
Doenças transmissíveis	Incidência	Chikung_12
Doenças transmissíveis	Incidência	Chikung_13
Doenças transmissíveis	Incidência	Chikung_14
Doenças transmissíveis	Incidência	Sifilis_08
Doenças transmissíveis	Incidência	Sifilis_09
Doenças transmissíveis	Incidência	Sifilis_10
Doenças transmissíveis	Incidência	Sifilis_11
Doenças transmissíveis	Incidência	Sifilis_12
Doenças transmissíveis	Incidência	Sifilis_13
Doenças transmissíveis	Incidência	Sifilis_14
Doenças transmissíveis	Incidência	SifCong_08
Doenças transmissíveis	Incidência	SifCong_09
Doenças transmissíveis	Incidência	SifCong_10
Doenças transmissíveis	Incidência	SifCong_11
Doenças transmissíveis	Incidência	SifCong_12
Doenças transmissíveis	Incidência	SifCong_13
Doenças transmissíveis	Incidência	SifCong_14"""

# %%
c = Categoria.objects.get(slug='morbidade', depth=1)

variaveis = {}

for subcat, subsubcat, var in [_.split("\t") for _ in morbidade_txt.upper().split("\n")]:
    variaveis.setdefault((subcat, subsubcat), set()).add(var)
    
variaveis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-28a0413dc33b> in <module>()
#       3 variaveis = {}
#       4
# ----> 5 for subcat, subsubcat, var in [_.split("\t") for _ in morbidade_txt.upper().split("\n")]:
#       6     variaveis.setdefault((subcat, subsubcat), set()).add(var)
#       7
#
# NameError: name 'morbidade_txt' is not defined

# %%
for s, ss in variaveis:
    slug = c.slug+'--'+"--".join([
            "-".join(unidecode(s).lower().split()),
            "-".join(unidecode(ss).lower().split()),
        ])
    try: 
        ssc = Categoria.objects.get(slug=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[(s, ss)]):
            print "encontrado", slug, "em:", i 
            i.categoria = ssc
            i.save()
# Out:
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de abandono de tratamento para Tuberculose
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de incidência de AIDS (em 100 mil habitantes)
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de incidência de Dengue (em 100 mil habitantes)
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de incidência de Febre Chikunguya (em 100 mil habitantes)
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de incidência de Sífilis (em 100 mil habitantes)
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de incidência de Sífilis Congênita (em 100 mil habitantes)
# encontrado morbidade--doencas-transmissiveis--taxas em: Taxa de incidência de Tuberculose (em 100 mil habitantes)
Cobertura 	Número de casos	ConsPreNatal_08
Cobertura 	Número de casos	ConsPreNatal_09
Cobertura 	Número de casos	ConsPreNatal_10
Cobertura 	Número de casos	ConsPreNatal_11
Cobertura 	Número de casos	ConsPreNatal_12
Cobertura 	Número de casos	ConsPreNatal_13
Cobertura 	Número de casos	ConsPreNatal_14"""

# %%
c = Categoria.objects.get(slug='cobertura', depth=1)

variaveis = {}

for subcat, subsubcat, var in [_.split("\t") for _ in cobertura_txt.upper().split("\n")]:
    variaveis.setdefault((subcat, subsubcat), set()).add(var)
    
variaveis
# Out:
# {(u'COBERTURA ', u'N\xdaMERO DE CASOS'): {u'CONSPRENATAL_08',
#   u'CONSPRENATAL_09',
#   u'CONSPRENATAL_10',
#   u'CONSPRENATAL_11',
#   u'CONSPRENATAL_12',
#   u'CONSPRENATAL_13',
#   u'CONSPRENATAL_14'},
#  (u'COBERTURA ', u'TAXAS'): {u'COBPOP_EAB_08',
#   u'COBPOP_EAB_09',
#   u'COBPOP_EAB_10',
#   u'COBPOP_EAB_11',
#   u'COBPOP_EAB_12',
#   u'COBPOP_EAB_13',
#   u'COBPOP_EAB_14',
#   u'COBPOP_EAB_15',
#   u'CONSMEDHAB_08',
#   u'CONSMEDHAB_09',
#   u'CONSMEDHAB_10',
#   u'CONSMEDHAB_11',
#   u'CONSMEDHAB_12',
#   u'CONSMEDHAB_13',
#   u'CONSMEDHAB_14',
#   u'P_BENEF_DEZ08',
#   u'P_BENEF_DEZ09',
#   u'P_BENEF_DEZ10',
#   u'P_BENEF_DEZ11',
#   u'P_BENEF_DEZ12',
#   u'P_BENEF_DEZ13',
#   u'P_BENEF_DEZ14',
#   u'P_BENEF_DEZ15',
#   u'P_NV7OUMAIS_08',
#   u'P_NV7OUMAIS_09',
#   u'P_NV7OUMAIS_10',
#   u'P_NV7OUMAIS_11',
#   u'P_NV7OUMAIS_12',
#   u'P_NV7OUMAIS_13',
#   u'P_NV7OUMAIS_14',
#   u'P_PARTOCES_08',
#   u'P_PARTOCES_09',
#   u'P_PARTOCES_10',
#   u'P_PARTOCES_11',
# ...

# %%
for s, ss in variaveis:
    slug = "--".join([
            "-".join(unidecode(s).lower().split()),
            "-".join(unidecode(ss).lower().split()),
        ])
    try: 
        ssc = Categoria.objects.get(slug=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[(s, ss)]):
            print "encontrado", slug, "em:", i 
            i.categoria = ssc
            i.save()
# Out:
# encontrado cobertura--taxas em: % de nascidos vivos de mães com 7 ou mais consultas de pré-natal
# encontrado cobertura--taxas em: % de partos cesáreos no total de partos
# encontrado cobertura--taxas em: % de partos cesáreos realizados no SUS no total de partos no SUS
# encontrado cobertura--taxas em: % de população beneficiária de planos de saúde
# encontrado cobertura--taxas em: Cobertura populacional estimada pelas equipes de Atenção Básica
# encontrado cobertura--taxas em: Consultas médicas por mil habitantes
Produção SUS	PAMB_ABHAB_09
Produção SUS	PAMB_ABHAB_10
Produção SUS	PAMB_ABHAB_11
Produção SUS	PAMB_ABHAB_12
Produção SUS	PAMB_ABHAB_13
Produção SUS	PAMB_ABHAB_14
Produção SUS	PAMB_MCHAB_08
Produção SUS	PAMB_MCHAB_09
Produção SUS	PAMB_MCHAB_10
Produção SUS	PAMB_MCHAB_11
Produção SUS	PAMB_MCHAB_12
Produção SUS	PAMB_MCHAB_13
Produção SUS	PAMB_MCHAB_14
Produção SUS	PAMB_ACHAB_08
Produção SUS	PAMB_ACHAB_09
Produção SUS	PAMB_ACHAB_10
Produção SUS	PAMB_ACHAB_11
Produção SUS	PAMB_ACHAB_12
Produção SUS	PAMB_ACHAB_13
Produção SUS	PAMB_ACHAB_14
Produção SUS	P_PA_AB_08
Produção SUS	P_PA_AB_09
Produção SUS	P_PA_AB_10
Produção SUS	P_PA_AB_11
Produção SUS	P_PA_AB_12
Produção SUS	P_PA_AB_13
Produção SUS	P_PA_AB_14
Produção SUS	P_PA_MC_08
Produção SUS	P_PA_MC_09
Produção SUS	P_PA_MC_10
Produção SUS	P_PA_MC_11
Produção SUS	P_PA_MC_12
Produção SUS	P_PA_MC_13
Produção SUS	P_PA_MC_14
Produção SUS	P_PA_AC_08
Produção SUS	P_PA_AC_09
Produção SUS	P_PA_AC_10
Produção SUS	P_PA_AC_11
Produção SUS	P_PA_AC_12
Produção SUS	P_PA_AC_13
Produção SUS	P_PA_AC_14
Produção SUS	P_PAPUBL_08
Produção SUS	P_PAPUBL_09
Produção SUS	P_PAPUBL_10
Produção SUS	P_PAPUBL_11
Produção SUS	P_PAPUBL_12
Produção SUS	P_PAPUBL_13
Produção SUS	P_PAPUBL_14
Produção SUS	P_PAPRIV_08
Produção SUS	P_PAPRIV_09
Produção SUS	P_PAPRIV_10
Produção SUS	P_PAPRIV_11
Produção SUS	P_PAPRIV_12
Produção SUS	P_PAPRIV_13
Produção SUS	P_PAPRIV_14
Produção SUS	P_PAPUBL_AB_08
Produção SUS	P_PAPUBL_AB_09
Produção SUS	P_PAPUBL_AB_10
Produção SUS	P_PAPUBL_AB_11
Produção SUS	P_PAPUBL_AB_12
Produção SUS	P_PAPUBL_AB_13
Produção SUS	P_PAPUBL_AB_14
Produção SUS	P_PAPRIV_AB_08
Produção SUS	P_PAPRIV_AB_09
Produção SUS	P_PAPRIV_AB_10
Produção SUS	P_PAPRIV_AB_11
Produção SUS	P_PAPRIV_AB_12
Produção SUS	P_PAPRIV_AB_13
Produção SUS	P_PAPRIV_AB_14
Produção SUS	P_PAPUBL_MC_08
Produção SUS	P_PAPUBL_MC_09
Produção SUS	P_PAPUBL_MC_10
Produção SUS	P_PAPUBL_MC_11
Produção SUS	P_PAPUBL_MC_12
Produção SUS	P_PAPUBL_MC_13
Produção SUS	P_PAPUBL_MC_14
Produção SUS	P_PAPRIV_MC_08
Produção SUS	P_PAPRIV_MC_09
Produção SUS	P_PAPRIV_MC_10
Produção SUS	P_PAPRIV_MC_11
Produção SUS	P_PAPRIV_MC_12
Produção SUS	P_PAPRIV_MC_13
Produção SUS	P_PAPRIV_MC_14
Produção SUS	P_PAPUBL_AC_08
Produção SUS	P_PAPUBL_AC_09
Produção SUS	P_PAPUBL_AC_10
Produção SUS	P_PAPUBL_AC_11
Produção SUS	P_PAPUBL_AC_12
Produção SUS	P_PAPUBL_AC_13
Produção SUS	P_PAPUBL_AC_14
Produção SUS	P_PAPRIV_AC_08
Produção SUS	P_PAPRIV_AC_09
Produção SUS	P_PAPRIV_AC_10
Produção SUS	P_PAPRIV_AC_11
Produção SUS	P_PAPRIV_AC_12
Produção SUS	P_PAPRIV_AC_13
Produção SUS	P_PAPRIV_AC_14
Produção SUS	TXINTHAB_08
Produção SUS	TXINTHAB_09
Produção SUS	TXINTHAB_10
Produção SUS	TXINTHAB_11
Produção SUS	TXINTHAB_12
Produção SUS	TXINTHAB_13
Produção SUS	TXINTHAB_14
Produção SUS	P_INTMC_08
Produção SUS	P_INTMC_09
Produção SUS	P_INTMC_10
Produção SUS	P_INTMC_11
Produção SUS	P_INTMC_12
Produção SUS	P_INTMC_13
Produção SUS	P_INTMC_14
Produção SUS	P_INTAC_08
Produção SUS	P_INTAC_09
Produção SUS	P_INTAC_10
Produção SUS	P_INTAC_11
Produção SUS	P_INTAC_12
Produção SUS	P_INTAC_13
Produção SUS	P_INTAC_14
Produção SUS	TXINTCCHAB_08
Produção SUS	TXINTCCHAB_09
Produção SUS	TXINTCCHAB_10
Produção SUS	TXINTCCHAB_11
Produção SUS	TXINTCCHAB_12
Produção SUS	TXINTCCHAB_13
Produção SUS	TXINTCCHAB_14
Produção SUS	TXINTCC_MCHAB_08
Produção SUS	TXINTCC_MCHAB_09
Produção SUS	TXINTCC_MCHAB_10
Produção SUS	TXINTCC_MCHAB_11
Produção SUS	TXINTCC_MCHAB_12
Produção SUS	TXINTCC_MCHAB_13
Produção SUS	TXINTCC_MCHAB_14
Produção SUS	TXINTCC_ACHAB_08
Produção SUS	TXINTCC_ACHAB_09
Produção SUS	TXINTCC_ACHAB_10
Produção SUS	TXINTCC_ACHAB_11
Produção SUS	TXINTCC_ACHAB_12
Produção SUS	TXINTCC_ACHAB_13
Produção SUS	TXINTCC_ACHAB_14
Produção SUS	MEDPERM_CLIN_08
Produção SUS	MEDPERM_CLIN_09
Produção SUS	MEDPERM_CLIN_10
Produção SUS	MEDPERM_CLIN_11
Produção SUS	MEDPERM_CLIN_12
Produção SUS	MEDPERM_CLIN_13
Produção SUS	MEDPERM_CLIN_14
Produção SUS	MEDPERM_CIR_08
Produção SUS	MEDPERM_CIR_09
Produção SUS	MEDPERM_CIR_10
Produção SUS	MEDPERM_CIR_11
Produção SUS	MEDPERM_CIR_12
Produção SUS	MEDPERM_CIR_13
Produção SUS	MEDPERM_CIR_14
Produção SUS	P_INTCCMC_08
Produção SUS	P_INTCCMC_09
Produção SUS	P_INTCCMC_10
Produção SUS	P_INTCCMC_11
Produção SUS	P_INTCCMC_12
Produção SUS	P_INTCCMC_13
Produção SUS	P_INTCCMC_14
Produção SUS	P_INTCCAC_08
Produção SUS	P_INTCCAC_09
Produção SUS	P_INTCCAC_10
Produção SUS	P_INTCCAC_11
Produção SUS	P_INTCCAC_12
Produção SUS	P_INTCCAC_13
Produção SUS	P_INTCCAC_14
Produção SUS	P_INTPUB_08
Produção SUS	P_INTPUB_09
Produção SUS	P_INTPUB_10
Produção SUS	P_INTPUB_11
Produção SUS	P_INTPUB_12
Produção SUS	P_INTPUB_13
Produção SUS	P_INTPUB_14
Produção SUS	P_INTMCPUB_08
Produção SUS	P_INTMCPUB_09
Produção SUS	P_INTMCPUB_10
Produção SUS	P_INTMCPUB_11
Produção SUS	P_INTMCPUB_12
Produção SUS	P_INTMCPUB_13
Produção SUS	P_INTMCPUB_14
Produção SUS	P_INTACPUB_08
Produção SUS	P_INTACPUB_09
Produção SUS	P_INTACPUB_10
Produção SUS	P_INTACPUB_11
Produção SUS	P_INTACPUB_12
Produção SUS	P_INTACPUB_13
Produção SUS	P_INTACPUB_14
Produção SUS	P_INTPRIV_08
Produção SUS	P_INTPRIV_09
Produção SUS	P_INTPRIV_10
Produção SUS	P_INTPRIV_11
Produção SUS	P_INTPRIV_12
Produção SUS	P_INTPRIV_13
Produção SUS	P_INTPRIV_14
Produção SUS	P_INTMCPRIV_08
Produção SUS	P_INTMCPRIV_09
Produção SUS	P_INTMCPRIV_10
Produção SUS	P_INTMCPRIV_11
Produção SUS	P_INTMCPRIV_12
Produção SUS	P_INTMCPRIV_13
Produção SUS	P_INTMCPRIV_14
Produção SUS	P_INTACPRIV_08
Produção SUS	P_INTACPRIV_09
Produção SUS	P_INTACPRIV_10
Produção SUS	P_INTACPRIV_11
Produção SUS	P_INTACPRIV_12
Produção SUS	P_INTACPRIV_13
Produção SUS	P_INTACPRIV_14""".replace(u"Fíisicos", u"Físicos")

# %%
c = Categoria.objects.get(slug='estrutura', depth=1)

variaveis = {}

for subcat, var in [_.split("\t") for _ in estrutura_txt.upper().split("\n")]:
    variaveis.setdefault(subcat, set()).add(var)
    
variaveis
# Out:
# {u'FINANCIAMENTO': {u'DRPSAUDE_HAB_08',
#   u'DRPSAUDE_HAB_09',
#   u'DRPSAUDE_HAB_10',
#   u'DRPSAUDE_HAB_11',
#   u'DRPSAUDE_HAB_12',
#   u'DRPSAUDE_HAB_13',
#   u'DRPSAUDE_HAB_14',
#   u'DTOTSAUDEHAB_08',
#   u'DTOTSAUDEHAB_09',
#   u'DTOTSAUDEHAB_10',
#   u'DTOTSAUDEHAB_11',
#   u'DTOTSAUDEHAB_12',
#   u'DTOTSAUDEHAB_13',
#   u'DTOTSAUDEHAB_14',
#   u'P_DINV_DTOT_08',
#   u'P_DINV_DTOT_09',
#   u'P_DINV_DTOT_10',
#   u'P_DINV_DTOT_11',
#   u'P_DINV_DTOT_12',
#   u'P_DINV_DTOT_13',
#   u'P_DINV_DTOT_14',
#   u'P_DPES_DTOT_08',
#   u'P_DPES_DTOT_09',
#   u'P_DPES_DTOT_10',
#   u'P_DPES_DTOT_11',
#   u'P_DPES_DTOT_12',
#   u'P_DPES_DTOT_13',
#   u'P_DPES_DTOT_14',
#   u'P_DSTERC_DTOT_08',
#   u'P_DSTERC_DTOT_09',
#   u'P_DSTERC_DTOT_10',
#   u'P_DSTERC_DTOT_11',
#   u'P_DSTERC_DTOT_12',
#   u'P_DSTERC_DTOT_13',
#   u'P_DSTERC_DTOT_14',
#   u'P_RPSAUDE_08',
#   u'P_RPSAUDE_09',
#   u'P_RPSAUDE_10',
#   u'P_RPSAUDE_11',
#   u'P_RPSAUDE_12',
#   u'P_RPSAUDE_13',
#   u'P_RPSAUDE_14',
# ...

# %%
for s in variaveis:
    slug = "--".join(['estrutura'] + [
            "-".join(unidecode(s).lower().split()),
        ])
    try: 
        sc = Categoria.objects.get(slug=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[s]):
            print "encontrado", slug, "em:", i 
            i.categoria = sc
            i.save()
# Out:
# encontrado estrutura--recursos-fisicos em: Número de aparelhos de ressonância magnética
# encontrado estrutura--recursos-fisicos em: Número de aparelhos de ressonância magnética por 100 mil habitantes
# encontrado estrutura--recursos-fisicos em: Número de exames de ressonância magnética por mil habitantes
# encontrado estrutura--recursos-fisicos em: Número de exames de ultrassonografia por mil habitantes
# encontrado estrutura--recursos-fisicos em: Número de tomógrafos computadorizados
# encontrado estrutura--recursos-fisicos em: Número de tomógrafos computadorizados por 100 mil habitantes
# encontrado estrutura--recursos-fisicos em: Porcentual de leitos SUS no total de leitos de internação
# encontrado estrutura--recursos-fisicos em: Total de hospitais
# encontrado estrutura--recursos-fisicos em: Total de leitos de internação
# encontrado estrutura--recursos-fisicos em: Total de leitos de internação por mil habitantes
# ...

# %%
org_txt = u"""Capacidade Administrativa	ORGSAU_14
Capacidade Administrativa	CONSSAU_14
Capacidade Administrativa	FUNDSAU_14
Capacidade Administrativa	PLANSAU_14
Capacidade Administrativa	CONFSAU_14
Capacidade Administrativa	COLEG_14"""

# %%
c = Categoria.objects.get(slug='politica-e-governanca', depth=1)

variaveis = {}

for subcat, var in [_.split("\t") for _ in org_txt.upper().split("\n")]:
    variaveis.setdefault(subcat, set()).add(var)
    
variaveis
# Out:
# {u'CAPACIDADE ADMINISTRATIVA': {u'COLEG_14',
#   u'CONFSAU_14',
#   u'CONSSAU_14',
#   u'FUNDSAU_14',
#   u'ORGSAU_14',
#   u'PLANSAU_14'}}

# %%
for s in variaveis:
    slug = "--".join(['politica-e-governanca'] + [
            "-".join(unidecode(s).lower().split()),
        ])
    try: 
        sc = Categoria.objects.get(slug=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[s]):
            print "encontrado", slug, "em:", i 
            i.categoria = sc
            i.save()
# Out:
# encontrado politica-e-governanca--capacidade-administrativa em: Caracterização do órgão gestor
# encontrado politica-e-governanca--capacidade-administrativa em: Conferência municipal de saúde - existência
# encontrado politica-e-governanca--capacidade-administrativa em: Conselho municipal de saúde - existência
# encontrado politica-e-governanca--capacidade-administrativa em: Fundo municipal de saúde - existência
# encontrado politica-e-governanca--capacidade-administrativa em: Órgão gestor da saúde faz parte de algum Colegiado de Gestão Regional
# encontrado politica-e-governanca--capacidade-administrativa em: Plano municipal de saúde - existência

# %%
c
# Out:
# <Categoria: Estrutura>

# %%
c.indicador()
# Out:
# <Indicador: % da produção ambulatorial de alta complexidade do prestador privado no total da produção ambulatorial de alta complexidade>

# %%
Categoria.objects.filter(depth=1, home=True).exclude(slug='fluxos-dos-servicos-de-saude').order_by('ordem').count()
# Out:
# 10

# %%
risco_txt = u"""Saúde	Taxas	ICSAB_08
Saúde	Taxas	ICSAB_09
Saúde	Taxas	ICSAB_10
Saúde	Taxas	ICSAB_11
Saúde	Taxas	ICSAB_12
Saúde	Taxas	ICSAB_13
Saúde	Taxas	ICSAB_14
Saúde	Taxas	P_NVBPN_08
Saúde	Taxas	P_NVBPN_09
Saúde	Taxas	P_NVBPN_10
Saúde	Taxas	P_NVBPN_11
Saúde	Taxas	P_NVBPN_12
Saúde	Taxas	P_NVBPN_13
Saúde	Taxas	P_NVBPN_14
Saúde	Taxas	P_NVMA_08
Saúde	Taxas	P_NVMA_09
Saúde	Taxas	P_NVMA_10
Saúde	Taxas	P_NVMA_11
Saúde	Taxas	P_NVMA_12
Saúde	Taxas	P_NVMA_13
Saúde	Taxas	P_NVMA_14
Saúde	Valores absolutos	InternCS_08
Saúde	Valores absolutos	InternCS_09
Saúde	Valores absolutos	InternCS_10
Saúde	Valores absolutos	InternCS_11
Saúde	Valores absolutos	InternCS_12
Saúde	Valores absolutos	InternCS_13
Saúde	Valores absolutos	InternCS_14
Saúde	Valores absolutos	NVBPN_08
Saúde	Valores absolutos	NVBPN_09
Saúde	Valores absolutos	NVBPN_10
Saúde	Valores absolutos	NVBPN_11
Saúde	Valores absolutos	NVBPN_12
Saúde	Valores absolutos	NVBPN_13
Saúde	Valores absolutos	NVBPN_14
Saúde	Valores absolutos	NVMA_08
Saúde	Valores absolutos	NVMA_09
Saúde	Valores absolutos	NVMA_10
Saúde	Valores absolutos	NVMA_11
Saúde	Valores absolutos	NVMA_12
Saúde	Valores absolutos	NVMA_13
Saúde	Valores absolutos	NVMA_14
Vulnerabilidade social	Taxas	DEPIDOSO_10
Vulnerabilidade social	Taxas	CRIMORAFUNDINC_10
Vulnerabilidade social	Taxas	MULCHFIF014_10
Vulnerabilidade social	Taxas	PES1524_NESTNTR_10
Vulnerabilidade social	Taxas	P_MUL15A17CF_10
Vulnerabilidade social	Taxas	OCDESLOC_10
Vulnerabilidade social	Taxas	DENSDOM_10
Vulnerabilidade social	Taxas	PAREDEDOM_10
Vulnerabilidade social	Valores absolutos	POP_PBF_15"""

# %%
c = Categoria.objects.get(slug='fatores-de-risco-e-protecao', depth=1)

variaveis = {}

for subcat, subsubcat, var in [_.split("\t") for _ in risco_txt.upper().split("\n")]:
    variaveis.setdefault((subcat, subsubcat), set()).add(var)
    
variaveis
# Out:
# {(u'SA\xdaDE', u'TAXAS'): {u'ICSAB_08',
#   u'ICSAB_09',
#   u'ICSAB_10',
#   u'ICSAB_11',
#   u'ICSAB_12',
#   u'ICSAB_13',
#   u'ICSAB_14',
#   u'P_NVBPN_08',
#   u'P_NVBPN_09',
#   u'P_NVBPN_10',
#   u'P_NVBPN_11',
#   u'P_NVBPN_12',
#   u'P_NVBPN_13',
#   u'P_NVBPN_14',
#   u'P_NVMA_08',
#   u'P_NVMA_09',
#   u'P_NVMA_10',
#   u'P_NVMA_11',
#   u'P_NVMA_12',
#   u'P_NVMA_13',
#   u'P_NVMA_14'},
#  (u'SA\xdaDE', u'VALORES ABSOLUTOS'): {u'INTERNCS_08',
#   u'INTERNCS_09',
#   u'INTERNCS_10',
#   u'INTERNCS_11',
#   u'INTERNCS_12',
#   u'INTERNCS_13',
#   u'INTERNCS_14',
#   u'NVBPN_08',
#   u'NVBPN_09',
#   u'NVBPN_10',
#   u'NVBPN_11',
#   u'NVBPN_12',
#   u'NVBPN_13',
#   u'NVBPN_14',
#   u'NVMA_08',
#   u'NVMA_09',
#   u'NVMA_10',
#   u'NVMA_11',
#   u'NVMA_12',
#   u'NVMA_13',
#   u'NVMA_14'},
#  (u'VULNERABILIDADE SOCIAL', u'TAXAS'): {u'CRIMORAFUNDINC_10',
#   u'DENSDOM_10',
#   u'DEPIDOSO_10',
#   u'MULCHFIF014_10',
#   u'OCDESLOC_10',
#   u'PAREDEDOM_10',
# ...

# %%
for s, ss in variaveis:
    slug = "--".join([c.slug]+[
            "-".join(unidecode(s).lower().split()),
            "-".join(unidecode(ss).lower().split()),
        ])
    try: 
        ssc = Categoria.objects.get(slug=slug)
    except Categoria.DoesNotExist:
        print "categoria nao encontrada para slug", slug
        continue
    for i in Indicador.objects.all():
        vars = set(i.observacao.upper().split(','))
        if vars.intersection(variaveis[(s, ss)]):
            print "encontrado", slug, "em:", i 
            i.categoria = ssc
            i.save()
# Out:
# encontrado fatores-de-risco-e-protecao--saude--valores-absolutos em: Internações por causas selecionadas sensíveis à atenção básica
# encontrado fatores-de-risco-e-protecao--saude--valores-absolutos em: Nascidos vivos de mães com até 19 anos
# encontrado fatores-de-risco-e-protecao--saude--valores-absolutos em: Nascidos vivos de mães com com peso ao nascer inferior a 2.500 gramas
# encontrado fatores-de-risco-e-protecao--vulnerabilidade-social--valores-absolutos em: População beneficiária do PBF
# encontrado fatores-de-risco-e-protecao--saude--taxas em: % de nascidos vivos de mães adolescentes
# encontrado fatores-de-risco-e-protecao--saude--taxas em: % de nascidos vivos de mães com baixo peso ao nascer
# encontrado fatores-de-risco-e-protecao--saude--taxas em: Proporção de internações por condições sensíveis à atenção básica
# ...
