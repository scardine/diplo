# %%
import os
os.environ['DYLD_LIBRARY_PATH']='/Users/paulos/.virtualenvs/diplo/lib/python2.7/site-packages/savReaderWriter/spssio/macos/'

# %%
from savReaderWriter import SavHeaderReader

with SavHeaderReader('Base Projeto BID.sav') as header:
    metadata = header.all()
    report = str(header)

# %%
report.split('#VARLABELS')[1].split('#')[0].split('\n')
# Out:
# ['',
#  'AGUA_10 -- Percentual de pessoas residentes em domic\xedlios com acesso \xe0 abastecimento de \xe1gua (2010)',
#  'AIDS_08 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2008)',
#  'AIDS_09 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2009)',
#  'AIDS_10 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2010)',
#  'AIDS_11 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2011)',
#  'AIDS_12 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2012)',
#  'AIDS_13 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2013)',
#  'AIDS_14 -- N\xfamero de casos de AIDS (SES) - munic\xedpio de resid\xeancia (2014)',
#  'AbandTub_08 -- N\xfamero de casos de abandono de tratamento para Tuberculose (2008)',
#  'AbandTub_09 -- N\xfamero de casos de abandono de tratamento para Tuberculose (2009)',
# ...

# %%
header.varLabels
# Out:
# ---------------------------------------------------------------------------
# SPSSIOError                               Traceback (most recent call last)
# <ipython-input-18-aee3e924e650> in <module>()
# ----> 1 header.varLabels
#
# /Users/paulos/.virtualenvs/diplo/lib/python2.7/site-packages/savReaderWriter/header.pyc in wrapper(arg)
#      49         @functools.wraps(func)
#      50         def wrapper(arg):
# ---> 51             result = func(arg)
#      52             if not arg.ioUtf8 or arg.ioUtf8 == 2:
#      53                 return result  # unchanged
#
# /Users/paulos/.virtualenvs/diplo/lib/python2.7/site-packages/savReaderWriter/header.pyc in varLabels(self)
#     335             if retcode:
#     336                 msg = "Problem getting variable label of variable %r" % varName
# --> 337                 checkErrsWarns(msg, retcode)
#     338         return varLabels
#     339
#
# ...

# %%
print(metadata.valueLabels)
# Out:
# {'UFCOD': {11.0: 'Rond\xf4nia', 12.0: 'Acre', 13.0: 'Amazonas', 14.0: 'Roraima', 15.0: 'Par\xe1', 16.0: 'Amap\xe1', 17.0: 'Tocantins', 21.0: 'Maranh\xe3o', 22.0: 'Piau\xed', 23.0: 'Cear\xe1', 24.0: 'Rio Grande do Norte', 25.0: 'Para\xedba', 26.0: 'Pernambuco', 27.0: 'Alagoas', 28.0: 'Sergipe', 29.0: 'Bahia', 31.0: 'Minas Gerais', 32.0: 'Esp\xedrito Santo', 33.0: 'Rio de Janeiro', 35.0: 'S\xe3o Paulo', 41.0: 'Paran\xe1', 42.0: 'Santa Catarina', 43.0: 'Rio Grande do Sul', 50.0: 'Mato Grosso do Sul', 51.0: 'Mato Grosso', 52.0: 'Goi\xe1s', 53.0: 'Distrito Federal'}}

# %%
# Out:
# ---------------------------------------------------------------------------
# SPSSIOError                               Traceback (most recent call last)
# <ipython-input-12-d251a2f866f3> in <module>()
# ----> 1 header.dataDictionary()
#
# /Users/paulos/.virtualenvs/diplo/lib/python2.7/site-packages/savReaderWriter/savHeaderReader.pyc in dataDictionary(self, asNamedtuple)
#     109         if self.ioUtf8:
#     110             items = map(unicode, items)
# --> 111         metadata = dict([(item, getattr(self, item)) for item in items])
#     112         if asNamedtuple:
#     113             Meta = collections.namedtuple("Meta", " ".join(metadata.keys()))
#
# /Users/paulos/.virtualenvs/diplo/lib/python2.7/site-packages/savReaderWriter/header.pyc in wrapper(arg)
#      49         @functools.wraps(func)
#      50         def wrapper(arg):
# ---> 51             result = func(arg)
#      52             if not arg.ioUtf8 or arg.ioUtf8 == 2:
# ...

# %%
print(report)
# Out:
# #ALIGNMENTS
# AGUA_10 -- right
# AIDS_08 -- right
# AIDS_09 -- right
# AIDS_10 -- right
# AIDS_11 -- right
# AIDS_12 -- right
# AIDS_13 -- right
# AIDS_14 -- right
# AbandTub_08 -- right
# AbandTub_09 -- right
# AbandTub_10 -- right
# AbandTub_11 -- right
# AbandTub_12 -- right
# AbandTub_13 -- right
# AbandTub_14 -- right
# COBPOP_EAB_08 -- right
# COBPOP_EAB_09 -- right
# COBPOP_EAB_10 -- right
# COBPOP_EAB_11 -- right
# COBPOP_EAB_12 -- right
# COBPOP_EAB_13 -- right
# COBPOP_EAB_14 -- right
# COBPOP_EAB_15 -- right
# COLEG_14 -- left
# CONCL_ENFHAB_13 -- right
# CONCL_ENFHAB_14 -- right
# CONCL_MEDHAB_13 -- right
# CONCL_MEDHAB_14 -- right
# CONFSAU_14 -- left
# CONSMEDHAB_08 -- right
# CONSMEDHAB_09 -- right
# CONSMEDHAB_10 -- right
# CONSMEDHAB_11 -- right
# CONSMEDHAB_12 -- right
# CONSMEDHAB_13 -- right
# CONSMEDHAB_14 -- right
# CONSSAU_14 -- left
# CRIMORAFUNDINC_10 -- right
# CURSO_ENFERM_13 -- right
# CURSO_ENFERM_14 -- right
# CURSO_MEDIC_13 -- right
# ...
